# %% [markdown]
# # WebScraper 0.1

# %% [markdown]
# ## Phase 1

# %% [markdown]
# Progress Contain :
# - X-Path Finder
# - Bulk title scraper
#
# Status passed

# %%
pip install webdriver_manager

# %%
pip install selenium

# %%
# importing necessary packages
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# for holding the resultant list
element_list = []

for page in range(1, 3, 1):
	
	page_url = "https://www.siloamhospitals.com/cari-dokter/rumah-sakit/siloam-hospitals-sentosa"
	driver = webdriver.Chrome(ChromeDriverManager().install())
	driver.get(page_url)
	title = driver.find_elements_by_xpath("(//div[@class='r-result'])[1]")
	price = driver.find_elements_by_xpath("//div[@class='r-result']//div[2]//div[2]//table[1]")
    

	for i in range(len(title)):
		element_list.append([title[i].text, price[i].text])

print(element_list)

#closing the driver
driver.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Driver [/home/zegveld/.wdm/drivers/chromedriver/linux64/93.0.4577.63/chromedriver] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Driver [/home/zegveld/.wdm/drivers/chromedriver/linux64/93.0.4577.63/chromedriver] found in cache
# [['dr. Melly Faisha Rahma\nLihat Profile\nDokter Umum - Dokter Umum\nTersedia hari ini (Siloam Hospitals Sentosa)\nRawat Jalan Siloam Hospitals Sentosa\nHubungi Kami\nMinggu Senin Selasa Rabu Kamis Jumat Sabtu\n07:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n07:00 - 21:00\ndrg. Sarah Rosalina\nLihat Profile\nKedokteran Gigi - Dokter Gigi\nTersedia hari ini (Siloam Hospitals Sentosa)\nRawat Jalan Siloam Hospitals Sentosa\nHubungi Kami\nMinggu Senin Selasa Rabu Kamis Jumat Sabtu\n-\n-\n17:00 - 20:00\n-\n17:00 - 20:00\n-\n-\nDr. LUXIANA SIAGIAN\nLihat Profile\nDokter Umum - Dokter Umum\nTersedia hari ini (Siloam Hospitals Sentosa)\nRawat Jalan Siloam Hospitals Sentosa\nHubungi Kami\nMinggu Senin Selasa Rabu Kamis Jumat Sabtu\n07:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n08:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n07:00 - 21:00\ndr. Yohanna Octaviany Gultom\nDokter Umum - Dokter Umum\nTersedia hari ini (Siloam Hospitals Sentosa)\nRawat Jalan Siloam Hospitals Sentosa\nHubungi Kami\nMinggu Senin Selasa Rabu Kamis Jumat Sabtu\n07:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n16:00 - 21:00\n16: